# %%
import numpy as np
import matplotlib.pyplot as plt
import pdb
import time
# PARÁMETROS DE SINTONIZACIÓN
Lambda=2
ld = 15
Kd =1
Gamma = 0.008
s_lim=0.015
# PARÁMETROS DE CONTROL
Ld = ld*I
# DATOS DEL SUB-SISTEMA MECANICO
# Masas
m1 = 0.105
m2 = 0.142
m3=0.135
m4=0.236
#Longitudes de los eslabones
l1_z = 0.0266
L1_z=0.043
L0_z=0.034
l2_y=0.106
L2_x=-0.024
L2_y=0.128
l3_y=0.0933
L3_y=0.124
l4_y=0.060
L4_y=0.126
# Inercias de eslabones y motores
Ixx1=107819*1e-09
Iyy1=103553*1e-09
Izz1=17644*1e-09
Ixx2=1836523*1e-09
Iyy2=1856215*1e-09
Izz2=54940*1e-09
Ixx3=1358961*1e-09
Iyy3=1350228*1e-09
Izz3=24835*1e-09
Ixx4=1128335*1e-09
Iyy4=1077791*1e-09
Izz4=182774*1e-09
Jm=0.0000071
Jg=0.0000053
# Jeq=(n**2)*Jm+Jg
Jeq=0.0037
#Gravedad y relacion de trnasmision
#   n=353.5
n=353.5
g=-9.81
#Constantes de friccion motores:
# Bm=0.0001 Bg=0.01 
# Beq=(n**2)*Bm+Bg
Beq=0.00012
# DATOS DEL SUB-SISTEMA ELECTRICO
#   Km=0.0458 Kb=0.0458 KA=8.5 Ra=2.49Ka=8.5
Km=0.005
Kb=1
KA=1
Ra=1
Ka=1  
# Keq=Beq+(n**2)*Km*Kb/Ra
Keq=Beq
U_lin=1/(Km*n)
# PARAMETROS DEL MODELO DINAMICO:
ae1=l2_y*m2
ae2=l2_y**2*m2
ae3=m3
ae4=l3_y*m3
ae5=l3_y**2*m3
ae6=m4
ae7=l4_y*m4
ae8=l4_y**2*m4
ae9=Izz1
ae10=Iyy2
ae11=(Ixx2+Izz2)
ae12=(Izz2-Ixx2)
ae13=(Ixx2-Izz2)
ae14=Iyy3
ae15=(Ixx3+Izz3)
ae16=(Izz3-Ixx3)
ae17=(Ixx3-Izz3)
ae18=Iyy4
ae19=(Ixx4+Izz4)
ae20=(Izz4-Ixx4)
ae21=(Ixx4-Izz4)
ae22=Jeq
ae23=Keq

# Iniciaalizar parámetros

qe1=0
qe2=0
qe3=0
qe4=0

dq1=0
dq2=0
dq3=0
dq4=0

dq_vec=np.array([[0],[0],[0],[0]], dtype=np.float64)
u_vec=np.array([[0],[0],[0],[0]], dtype=np.float64)
q1=np.deg2rad(0)
q2=np.deg2rad(-20)
q3=np.deg2rad(0)
q4=np.deg2rad(-70)
'''
q = [np.deg2rad(0)np.deg2rad(-20)np.deg2rad(0)np.deg2rad(-70)]
dq=[0000]
qe=[np.deg2rad(0)
    np.deg2rad(-20)np.deg2rad(0)np.deg2rad(-70)] 
dqe=[0000]
dqd = [0000]
ddqd = [0000]
qd=[0000]
qtilde = [0000]
dqtilde = [0000]
dqr = [0000]
ddqr = [0000]
s = [0000]
'''

# TIEMPO DE MUESTREO
T = 0.02

# VALORES PARA GENERACION DE TRAYECTORIAS
Tp = 5
A = 0.5
nn = 1000 
#   if(tap==0)
#     B = 0.0005 
#   else
#     B = 0.001
#   end

# VARIABLES PARA ALMACENAR DATOS
Q1=np.zeros((1,nn), dtype=np.float64)
Q2=np.zeros((1,nn), dtype=np.float64)
Q3=np.zeros((1,nn), dtype=np.float64)
Q4=np.zeros((1,nn), dtype=np.float64)
Qd1=np.zeros((1,nn), dtype=np.float64)
Qd2=np.zeros((1,nn), dtype=np.float64)
Qd3=np.zeros((1,nn), dtype=np.float64)
Qd4=np.zeros((1,nn), dtype=np.float64)
U1=np.zeros((1,nn), dtype=np.float64)
U2=np.zeros((1,nn), dtype=np.float64)
U3=np.zeros((1,nn), dtype=np.float64)
U4=np.zeros((1,nn), dtype=np.float64)


# LAZO DE CONTROL
for k in np.arange(0, nn):

    #     GENERACIÓN DE LA TRAYECTORIA

    #   REFERENCIAS  DESEADAS qd1 Y qd2 Sinusoidal
    #   qd1 = A*np.sin(W*k)+B*k Qd1(k) = qd1
    #   dqd1 = A*W*np.cos(W*k)+B 
    #   ddqd1 = -A*W**2*np.sin(W*k)
    #   qd2 = A*np.cos(W*k)+B*k Qd2(k) = qd2
    #   dqd2 = -A*W*np.sin(W*k)+B
    #   ddqd2 = -A*W**2*np.cos(W*k)
    #   qd3 = -np.sin(W*k)-B*k Qd3(k) = qd3 
    #   dqd3 = W*np.cos(W*k)-B 
    #   ddqd3 = -W**2*np.sin(W*k) 
    #   qd4= -np.cos(W*k)Qd4(k) = qd4 
    #   dqd4= W*np.sin(W*k)
    #   ddqd4= W**2*np.cos(W*k)
    #   qd=[qd1qd2qd3qd4]
    #   dqd =  [dqd1dqd2dqd3dqd4]
    #   ddqd = [ddqd1ddqd2ddqd3ddqd4]

    # REFERENCIAS DESEADAS Cuadradas
    if k >= 0 and k <= nn/4:
        qd1 = np.deg2rad(0)
        qd2=np.deg2rad(-20)
        qd3= np.deg2rad(0)
        qd4 = np.deg2rad(-70)
    elif k >= nn/4 and k <= nn/2:
        qd1 = 0.2*A
        qd2 = np.deg2rad(0)
        qd3 =np.deg2rad(10)
        qd4 = np.deg2rad(0)
    elif k >= nn/2 and k <= 3*nn/4:
        qd1 = 0.8*A
        qd2 = np.deg2rad(20)
        qd3 = np.deg2rad(-10)
        qd4 = np.deg2rad(20)
    elif k >= 3*nn/4 and k <= nn:
        qd1 = 0.3*A
        qd2 = np.deg2rad(-10)
        qd3 = np.deg2rad(20)
        qd4 = np.deg2rad(-40)

    Qd1[0,k] = qd1
    Qd2[0,k] = qd2
    Qd3[0,k] = qd3
    Qd4[0,k] = qd4
    dqd1 = 0
    dqd2 = 0
    dqd3 = 0
    dqd4 = 0

    ddqd1 = 0
    ddqd2 = 0
    ddqd3 = 0
    ddqd4 = 0
    
    # OBSERVADOR DE VELOCIDAD
    dqe1 = dqd1 + ld*(q1 - qe1)
    dqe2 = dqd2 + ld*(q2 - qe2)
    dqe3 = dqd3 + ld*(q3 - qe3)
    dqe4 = dqd4 + ld*(q4 - qe4)
    
    qe1 = qe1 + T*dqe1
    qe2 = qe2 + T*dqe2
    qe3 = qe3 + T*dqe3
    qe4 = qe4 + T*dqe4
    
    # ERROR DE POSICION Y DE VELOCIDAD   
    qtilde1 = q1 - qd1
    qtilde2 = q2 - qd2
    qtilde3 = q3 - qd3
    qtilde4 = q4 - qd4
    
    dqtilde1 = dqe1 - dqd1
    dqtilde2 = dqe2 - dqd2
    dqtilde3 = dqe3 - dqd3
    dqtilde4 = dqe4 - dqd4
    
    # VELOCIDAD Y ACELERACION DE REFERENCIA
    dqr1 = dqd1 - Lambda*qtilde1
    dqr2 = dqd2 - Lambda*qtilde2
    dqr3 = dqd3 - Lambda*qtilde3
    dqr4 = dqd4 - Lambda*qtilde4
    
    ddqr1 = ddqd1 - Lambda*dqtilde1
    ddqr2 = ddqd2 - Lambda*dqtilde2
    ddqr3 = ddqd3 - Lambda*dqtilde3
    ddqr4 = ddqd4 - Lambda*dqtilde4
    
    # MATRIZ Y DE PARÁMETROS NO LINEALES
    sig1=(2*qe2 + 2*qe3 + 2*qe4)
    sig2=(2*qe2 + 2*qe3 + qe4)
    sig3=(2*qe2 + qe3 + qe4)
    sig4=(qe2 + qe3 + qe4)
    sig5=(2*qe2 + 2*qe3)
    sig6=(2*qe2 + qe3)
    # Tau1=
    Y11=0
    Y12=ddqr1/2 - ddqr1*np.cos(2*qe2)/2 + dqe1*dqe2*np.sin(2*qe2)
    Y13=(L2_x**2*ddqr1)/2 + (L2_x**2*ddqr1*np.cos(2*qe2))/2 - L2_x**2*dqe1*dqe2*np.sin(2*qe2)+ (L2_y**2*ddqr1)/2 - (L2_y**2*ddqr1*np.cos(2*qe2))/2 + L2_y**2*dqe1*dqe2*np.sin(2*qe2) - L2_x*L2_y*ddqr1*np.sin(2*qe2) - 2*L2_x*L2_y*dqe1*dqe2*np.cos(2*qe2)  
    Y14=L2_x*ddqr1*np.cos(qe3) - L2_y*ddqr1*np.sin(sig6) + L2_y*ddqr1*np.sin(qe3) + L2_x*ddqr1*np.cos(sig6) + L2_y*dqe1*dqe3*np.cos(qe3) - L2_x*dqe1*dqe3*np.sin(qe3) - 2*L2_y*dqe1*dqe2*np.cos(sig6) - L2_y*dqe1*dqe3*np.cos(sig6) - 2*L2_x*dqe1*dqe2*np.sin(sig6) - L2_x*dqe1*dqe3*np.sin(sig6) 
    Y15=((ddqr1)/2 + (ddqr1*np.cos(sig5))/2 - dqe1*dqe2*np.sin(sig5) - dqe1*dqe3*np.sin(sig5)) 
    Y16=(L2_x**2*ddqr1)/2 + (L2_x**2*ddqr1*np.cos(2*qe2))/2 - L2_x**2*dqe1*dqe2*np.sin(2*qe2) + (L2_y**2*ddqr1)/2 - (L2_y**2*ddqr1*np.cos(2*qe2))/2 + L2_y**2*dqe1*dqe2*np.sin(2*qe2) + (L3_y**2*ddqr1)/2 + (L3_y**2*ddqr1*np.cos(sig5))/2 - L3_y**2*dqe1*dqe2*np.sin(sig5) - L3_y**2*dqe1*dqe3*np.sin(sig5) + L2_x*L3_y*ddqr1*np.cos(qe3) + L2_y*L3_y*ddqr1*np.sin(qe3) + L2_x*L3_y*ddqr1*np.cos(sig6) - L2_y*L3_y*ddqr1*np.sin(sig6) + L2_y*L3_y*dqe1*dqe3*np.cos(qe3) - L2_x*L3_y*dqe1*dqe3*np.sin(qe3) - 2*L2_y*L3_y*dqe1*dqe2*np.cos(sig6) - L2_y*L3_y*dqe1*dqe3*np.cos(sig6) - 2*L2_x*L3_y*dqe1*dqe2*np.sin(sig6) - L2_x*L3_y*dqe1*dqe3*np.sin(sig6) - L2_x*L2_y*ddqr1*np.sin(2*qe2) - 2*L2_x*L2_y*dqe1*dqe2*np.cos(2*qe2) 
    Y17=(L2_x*ddqr1*np.cos(sig3) - L2_y*ddqr1*np.sin(sig3) + L2_x*ddqr1*np.cos(qe3 + qe4) + L2_y*ddqr1*np.sin(qe3 + qe4) + L3_y*ddqr1*np.cos(qe4) + L3_y*ddqr1*np.cos(sig2) + L2_y*dqe1*dqe3*np.cos(qe3 + qe4) + L2_y*dqe1*dqe4)*np.cos(qe3 + qe4) - L2_x*dqe1*dqe3*np.sin(qe3 + qe4) - L2_x*dqe1*dqe4*np.sin(qe3 + qe4) - L3_y*dqe1*dqe4*np.sin(qe4) - 2*L3_y*dqe1*dqe2*np.sin(sig2) - 2*L3_y*dqe1*dqe3*np.sin(sig2) - L3_y*dqe1*dqe4*np.sin(sig2) - 2*L2_y*dqe1*dqe2*np.cos(sig3) - L2_y*dqe1*dqe3*np.cos(sig3) - L2_y*dqe1*dqe4*np.cos(sig3) - 2*L2_x*dqe1*dqe2*np.sin(sig3) - L2_x*dqe1*dqe3*np.sin(sig3) - L2_x*dqe1*dqe4*np.sin(sig3) 
    Y18=((ddqr1)/2 - dqe1*dqe2*np.sin(sig1) + (ddqr1*np.cos(sig1))/2 - dqe1*dqe3*np.sin(sig1) - dqe1*dqe4)*np.sin(sig1) 
    Y19=ddqr1 
    Y110=0
    Y111=ddqr1/2 
    Y112=ddqr1*np.cos(2*qe2)/2 
    Y113=dqe1*dqe2*np.sin(2*qe2) 
    Y114=0
    Y115=ddqr1/2 
    Y116=dqe1*dqe2*np.sin(sig5) + dqe1*dqe3*np.sin(sig5) 
    Y117=ddqr1*np.cos(sig5)/2 
    Y118=0
    Y119=ddqr1/2 
    Y120=(dqe1*dqe2*np.sin(sig1) + dqe1*dqe3*np.sin(sig1) + dqe1*dqe4)*np.sin(sig1) 
    Y121=ddqr1*np.cos(sig1)/2 
    Y122=ddqr1 
    Y123=dqe1 
    # Tau2=
    Y21=g*np.sin(qe2) 
    Y22=(ddqr2 - (dqe1**2*np.sin(2*qe2))/2) 
    Y23=(L2_x**2*ddqr2 + (L2_x**2*dqe1**2*np.sin(2*qe2))/2 + L2_y**2*ddqr2 - (L2_y**2*dqe1**2*np.sin(2*qe2))/2 + L2_x*L2_y*dqe1**2*np.cos(2*qe2) - L2_x*g*np.cos(qe2) + L2_y*g*np.sin(qe2)) 
    Y24=(L2_y*dqe3**2*np.cos(qe3) - g*np.cos(qe2 + qe3) - L2_x*dqe3**2*np.sin(qe3) + L2_y*dqe1**2*np.cos(sig6) + L2_x*dqe1**2*np.sin(sig6) + 2*L2_x*ddqr2*np.cos(qe3) + L2_x*ddqr3*np.cos(qe3) + 2*L2_y*ddqr2*np.sin(qe3) + L2_y*ddqr3*np.sin(qe3) + 2*L2_y*dqe2*dqe3*np.cos(qe3) - 2*L2_x*dqe2*dqe3*np.sin(qe3)) 
    Y25=(ddqr2 + ddqr3 + (dqe1**2*np.sin(sig5))/2) 
    Y26=(L2_x**2*ddqr2 + (L2_x**2*dqe1**2*np.sin(2*qe2))/2 + L2_y**2*ddqr2 + L3_y**2*ddqr2 + L3_y**2*ddqr3 + (L3_y**2*dqe1**2*np.sin(sig5))/2 - L3_y*g*np.cos(qe2 + qe3) - L2_x*g*np.cos(qe2) + L2_y*g*np.sin(qe2)  - (L2_y**2*dqe1**2*np.sin(2*qe2))/2 + L2_y*L3_y*dqe3**2*np.cos(qe3) - L2_x*L3_y*dqe3**2*np.sin(qe3) + L2_y*L3_y*dqe1**2*np.cos(sig6) + L2_x*L3_y*dqe1**2*np.sin(sig6) + L2_x*L2_y*dqe1**2*np.cos(2*qe2) + 2*L2_x*L3_y*ddqr2*np.cos(qe3) + L2_x*L3_y*ddqr3*np.cos(qe3) + 2*L2_y*L3_y*ddqr2*np.sin(qe3) + L2_y*L3_y*ddqr3*np.sin(qe3) + 2*L2_y*L3_y*dqe2*dqe3*np.cos(qe3) - 2*L2_x*L3_y*dqe2*dqe3*np.sin(qe3)) 
    Y27=(L3_y*dqe1**2*np.sin(sig2) - L2_x*dqe3**2*np.sin(qe3 + qe4) - L2_x*dqe4)**2*np.sin(qe3 + qe4) - L3_y*dqe4**2*np.sin(qe4) + 2*L2_x*ddqr2*np.cos(qe3 + qe4) + L2_x*ddqr3*np.cos(qe3 + qe4) + L2_x*ddqr4*np.cos(qe3 + qe4) + 2*L2_y*ddqr2*np.sin(qe3 + qe4) + L2_y*ddqr3*np.sin(qe3 + qe4) + L2_y*ddqr4*np.sin(qe3 + qe4) + 2*L3_y*ddqr2*np.cos(qe4) + 2*L3_y*ddqr3*np.cos(qe4) + L3_y*ddqr4*np.cos(qe4)+ L2_y*dqe1**2*np.cos(sig3) + L2_x*dqe1**2*np.sin(sig3) + L2_y*dqe3**2*np.cos(qe3 + qe4) + L2_y*dqe4**2*np.cos(qe3 + qe4) + 2*L2_y*dqe2*dqe3*np.cos(qe3 + qe4) + 2*L2_y*dqe2*dqe4*np.cos(qe3 + qe4) + 2*L2_y*dqe3*dqe4*np.cos(qe3 + qe4) - 2*L2_x*dqe2*dqe3*np.sin(qe3 + qe4) - 2*L2_x*dqe2*dqe4*np.sin(qe3 + qe4) - 2*L2_x*dqe3*dqe4*np.sin(qe3 + qe4) - 2*L3_y*dqe2*dqe4*np.sin(qe4) - 2*L3_y*dqe3*dqe4*np.sin(qe4) - g*np.cos(sig4) 
    Y28=(ddqr2 + ddqr3 + ddqr4 + (dqe1**2*np.sin(sig1))/2) 
    Y29=0
    Y210=ddqr2 
    Y211=0
    Y212=dqe1**2*np.sin(2*qe2)/2 
    Y213=0
    Y214=(ddqr2 + ddqr3) 
    Y215=0
    Y216=0
    Y217=dqe1**2*np.sin(sig5)/2 
    Y218=(ddqr2 + ddqr3 + ddqr4) 
    Y219=0
    Y220=0
    Y221=dqe1**2*np.sin(sig1)/2 
    Y222=ddqr2 
    Y223=dqe2 
    
    # Tau3=
    Y31=0
    Y32=0
    Y33=0
    Y34=(L2_x*dqe2**2*np.sin(qe3) - g*np.cos(qe2 + qe3) - L2_y*dqe2**2*np.cos(qe3) + L2_x*ddqr2*np.cos(qe3) + L2_y*ddqr2*np.sin(qe3) + L2_x*dqe1**2*np.sin(qe2 + qe3)*np.cos(qe2) - L2_y*dqe1**2*np.sin(qe2 + qe3)*np.sin(qe2)) 
    Y35=(ddqr2 + ddqr3 + dqe1**2*np.cos(qe2 + qe3)*np.sin(qe2 + qe3)) 
    Y36=(L3_y**2*ddqr2 + L3_y**2*ddqr3 + L3_y**2*dqe1**2*np.cos(qe2 + qe3)*np.sin(qe2 + qe3) - L3_y*g*np.cos(qe2 + qe3) - L2_y*L3_y*dqe2**2*np.cos(qe3) + L2_x*L3_y*dqe2**2*np.sin(qe3) + L2_x*L3_y*ddqr2*np.cos(qe3) + L2_y*L3_y*ddqr2*np.sin(qe3) + L2_x*L3_y*dqe1**2*np.sin(qe2 + qe3)*np.cos(qe2) - L2_y*L3_y*dqe1**2*np.sin(qe2 + qe3)*np.sin(qe2)) 
    Y37=(L2_x*dqe2**2*np.sin(qe3 + qe4) - g*np.cos(sig4) - L3_y*dqe4)**2*np.sin(qe4) + L2_x*ddqr2*np.cos(qe3 + qe4) + L2_y*ddqr2*np.sin(qe3 + qe4) + 2*L3_y*ddqr2*np.cos(qe4) + 2*L3_y*ddqr3*np.cos(qe4)+ L3_y*ddqr4*np.cos(qe4) - L2_y*dqe2**2*np.cos(qe3 + qe4) + L3_y*dqe1**2*np.cos(sig4)*np.sin(qe2 + qe3) + L3_y*dqe1**2*np.sin(sig4)*np.cos(qe2 + qe3) - 2*L3_y*dqe2*dqe4*np.sin(qe4) - 2*L3_y*dqe3*dqe4*np.sin(qe4) + L2_x*dqe1**2*np.sin(sig4)*np.cos(qe2) - L2_y*dqe1**2*np.sin(sig4)*np.sin(qe2) 
    Y38=(ddqr2 + ddqr3 + ddqr4 + dqe1**2*np.cos(sig4)*np.sin(sig4)) 
    Y39=0
    Y310=0
    Y311=0
    Y312=0
    Y313=0
    Y314=(ddqr2 + ddqr3) 
    Y315=0
    Y316=0
    Y317=dqe1**2*np.sin(sig5)/2 
    Y318=(ddqr2 + ddqr3 + ddqr4) 
    Y319=0
    Y320=0
    Y321=dqe1**2*np.sin(sig1)/2 
    Y322=ddqr3 
    Y323=dqe3
    
    # Tau4=0 
    Y41=0
    Y42=0
    Y43=0
    Y44=0
    Y45=0
    Y46=0
    Y47=(L2_x*dqe2**2*np.sin(qe3 + qe4) + L3_y*dqe2**2*np.sin(qe4) + L3_y*dqe3**2*np.sin(qe4) + L2_x*ddqr2*np.cos(qe3 + qe4) + L2_y*ddqr2*np.sin(qe3 + qe4) + L3_y*ddqr2*np.cos(qe4) + L3_y*ddqr3*np.cos(qe4) - L2_y*dqe2**2*np.cos(qe3 + qe4) + L3_y*dqe1**2*np.sin(sig4)*np.cos(qe2 + qe3) + 2*L3_y*dqe2*dqe3*np.sin(qe4) + L2_x*dqe1**2*np.sin(sig4)*np.cos(qe2) - L2_y*dqe1**2*np.sin(sig4)*np.sin(qe2) - g*np.cos(sig4)) 
    Y48=(ddqr2 + ddqr3 + ddqr4 + dqe1**2*np.cos(sig4)*np.sin(sig4)) 
    Y49=0
    Y410=0
    Y411=0
    Y412=0
    Y413=0
    Y414=0
    Y415=0
    Y416=0
    Y417=0
    Y418=(ddqr2 + ddqr3 + ddqr4) 
    Y419=0
    Y420=0
    Y421=dqe1**2*np.cos(sig4)*np.sin(sig4) 
    Y422=ddqr4 
    Y423=dqe4 

    
    # FUNCION DE DESLIZAMIENTO 
    s1 = dqtilde1 + Lambda*qtilde1
    s2 = dqtilde2 + Lambda*qtilde2
    s3 = dqtilde3 + Lambda*qtilde3
    s4 = dqtilde4 + Lambda*qtilde4

    # ESTIMACION DE PARAMETROS
    if (s1<s_lim) and (s1>-s_lim):
        ae1 = ae1 - T*Gamma*(Y11*s1 + Y21*s2 + Y31*s3 + Y41*s4)
        ae2 = ae2 - T*Gamma*(Y12*s1 + Y22*s2 + Y32*s3 + Y42*s4)
        ae3 = ae3 - T*Gamma*(Y13*s1 + Y23*s2 + Y33*s3 + Y43*s4)
        ae4 = ae4 - T*Gamma*(Y14*s1 + Y24*s2 + Y34*s3 + Y44*s4)
        ae5 = ae5 - T*Gamma*(Y15*s1 + Y25*s2 + Y35*s3 + Y45*s4)
        ae6 = ae6 - T*Gamma*(Y16*s1 + Y26*s2 + Y36*s3 + Y46*s4)
        ae7 = ae7 - T*Gamma*(Y17*s1 + Y27*s2 + Y37*s3 + Y47*s4)
        ae8 = ae8 - T*Gamma*(Y18*s1 + Y28*s2 + Y38*s3 + Y48*s4)
        ae9 = ae9 - T*Gamma*(Y19*s1 + Y29*s2 + Y39*s3 + Y49*s4)
        ae10 = ae10 - T*Gamma*(Y110*s1 + Y210*s2 + Y310*s3 + Y410*s4)
        ae11 = ae11 - T*Gamma*(Y111*s1 + Y211*s2 + Y311*s3 + Y411*s4)
        ae12 = ae12 - T*Gamma*(Y112*s1 + Y212*s2 + Y312*s3 + Y412*s4)
        ae13 = ae13 - T*Gamma*(Y113*s1 + Y213*s2 + Y313*s3 + Y413*s4)
        ae14 = ae14 - T*Gamma*(Y114*s1 + Y214*s2 + Y314*s3 + Y414*s4)
        ae15 = ae15 - T*Gamma*(Y115*s1 + Y215*s2 + Y315*s3 + Y415*s4)
        ae16 = ae16 - T*Gamma*(Y116*s1 + Y216*s2 + Y316*s3 + Y416*s4)
        ae17 = ae17 - T*Gamma*(Y117*s1 + Y217*s2 + Y317*s3 + Y417*s4)
        ae18 = ae18 - T*Gamma*(Y118*s1 + Y218*s2 + Y318*s3 + Y418*s4)
        ae19 = ae19 - T*Gamma*(Y119*s1 + Y219*s2 + Y319*s3 + Y419*s4)
        ae20 = ae20 - T*Gamma*(Y120*s1 + Y220*s2 + Y320*s3 + Y420*s4)
        ae21 = ae21 - T*Gamma*(Y121*s1 + Y221*s2 + Y321*s3 + Y421*s4)
        ae22 = ae22 - T*Gamma*(Y122*s1 + Y222*s2 + Y322*s3 + Y422*s4)
        ae23 = ae23 - T*Gamma*(Y123*s1 + Y223*s2 + Y323*s3 + Y423*s4)
 

    # LEY DE CONTROL 
    u1 = Y11*ae1 + Y12*ae2 + Y13*ae3 + Y14*ae4 + Y15*ae5 + Y16*ae6 + Y17*ae7 + Y18*ae8 + Y19*ae9 + Y110*ae10 + Y111*ae11 + Y112*ae12 + Y113*ae13 + Y114*ae14 + Y115*ae15 + Y116*ae16 + Y117*ae17 + Y118*ae18 + Y119*ae19 + Y120*ae20 + Y121*ae21 + Y122*ae22 + Y123*ae23 - Kd*s1
    u2 = Y21*ae1 + Y22*ae2 + Y23*ae3 + Y24*ae4 + Y25*ae5 + Y26*ae6 + Y27*ae7 + Y28*ae8 + Y29*ae9 + Y210*ae10 + Y211*ae11 + Y212*ae12 + Y213*ae13 + Y214*ae14 + Y215*ae15 + Y216*ae16 + Y217*ae17 + Y218*ae18 + Y219*ae19 + Y220*ae20 + Y221*ae21 + Y222*ae22 + Y223*ae23 - Kd*s2
    u3 = Y31*ae1 + Y32*ae2 + Y33*ae3 + Y34*ae4 + Y35*ae5 + Y36*ae6 + Y37*ae7 + Y38*ae8 + Y39*ae9 + Y310*ae10 + Y311*ae11 + Y312*ae12 + Y313*ae13 + Y314*ae14 + Y315*ae15 + Y316*ae16 + Y317*ae17 + Y318*ae18 + Y319*ae19 + Y320*ae20 + Y321*ae21 + Y322*ae22 + Y323*ae23 - Kd*s3
    u4 = Y41*ae1 + Y42*ae2 + Y43*ae3 + Y44*ae4 + Y45*ae5 + Y46*ae6 + Y47*ae7 + Y48*ae8 + Y49*ae9 + Y410*ae10 + Y411*ae11 + Y412*ae12 + Y413*ae13 + Y414*ae14 + Y415*ae15 + Y416*ae16 + Y417*ae17 + Y418*ae18 + Y419*ae19 + Y420*ae20 + Y421*ae21 + Y422*ae22 + Y423*ae23 - Kd*s4
    U1[0,k] = u1
    U2[0,k] = u2
    U3[0,k] = u3
    U4[0,k] = u4

    # APLICACION DE LA LEY DE CONTROL AL SISTEMA
    # MODELO DINAMICO DEL SISTEMA 
    M11 = U_lin*(Ixx3 + Ixx4 + Izz1 + Izz2 + Jeq + m3*(l3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2))**2 - Ixx4*np.sin(q2 + q3 + q4)**2 + Izz4*np.sin(q2 + q3 + q4)**2 - Ixx3*np.sin(q2 + q3)**2 + Izz3*np.sin(q2 + q3)**2 + m4*(L3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2) + l4_y*np.cos(q2 + q3 + q4))**2 + Ixx2*np.sin(q2)**2 - Izz2*np.sin(q2)**2 + l2_y**2*m2*np.sin(q2)**2)
    M22 = U_lin*(Iyy2 + Iyy3 + Iyy4 + Jeq + L2_x**2*m3 + L2_x**2*m4 + L2_y**2*m3 + L2_y**2*m4 + L3_y**2*m4 + l2_y**2*m2 + l3_y**2*m3 + l4_y**2*m4 + 2*L2_x*l4_y*m4*np.cos(q3 + q4) + 2*L2_x*L3_y*m4*np.cos(q3) + 2*L2_y*l4_y*m4*np.sin(q3 + q4) + 2*L2_y*L3_y*m4*np.sin(q3) + 2*L2_x*l3_y*m3*np.cos(q3) + 2*L3_y*l4_y*m4*np.cos(q4) + 2*L2_y*l3_y*m3*np.sin(q3))
    M23 = U_lin*(Iyy3 + Iyy4 + L3_y**2*m4 + l3_y**2*m3 + l4_y**2*m4 + L2_x*l4_y*m4*np.cos(q3 + q4) + L2_x*L3_y*m4*np.cos(q3) + L2_y*l4_y*m4*np.sin(q3 + q4) + L2_y*L3_y*m4*np.sin(q3) + L2_x*l3_y*m3*np.cos(q3) + 2*L3_y*l4_y*m4*np.cos(q4) + L2_y*l3_y*m3*np.sin(q3))
    M24 = U_lin*((Iyy4 + l4_y*m4*(l4_y + L2_x*np.cos(q3 + q4) + L2_y*np.sin(q3 + q4) + L3_y*np.cos(q4))))
    M32 = M23
    M33 = U_lin*(Iyy3 + Iyy4 + Jeq + m4*(L3_y**2 + 2*np.cos(q4)*L3_y*l4_y + l4_y**2) + l3_y**2*m3)
    M34 = U_lin*(Iyy4 + m4*(l4_y**2 + L3_y*np.cos(q4)*l4_y))
    M42 = M24
    M43 = M34
    M44 = U_lin*(m4*l4_y**2 + Iyy4 + Jeq)
    M = np.array([[M11  ,  0   ,     0   ,    0] ,
                  [0 ,   M22  ,   M23   ,M24],
                  [0   , M32  ,   M33 ,  M34],
                  [0  ,  M42   ,  M43 ,  M44]], dtype=np.float64)
    ############
    P11 = U_lin*(Keq - dq3*((Ixx3*np.sin(2*q2 + 2*q3))/2 - (Izz3*np.sin(2*q2 + 2*q3))/2 + (Ixx4*np.sin(2*q2 + 2*q3 + 2*q4))/2 - (Izz4*np.sin(2*q2 + 2*q3 + 2*q4))/2 + m4*(L3_y*np.sin(q2 + q3) + l4_y*np.sin(q2 + q3 + q4))*(L3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2) + l4_y*np.cos(q2 + q3 + q4)) + l3_y*m3*np.sin(q2 + q3)*(l3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2))) - dq2*((Ixx3*np.sin(2*q2 + 2*q3))/2 - (Izz3*np.sin(2*q2 + 2*q3))/2 - (Ixx2*np.sin(2*q2))/2 + (Izz2*np.sin(2*q2))/2 + (Ixx4*np.sin(2*q2 + 2*q3 + 2*q4))/2 - (Izz4*np.sin(2*q2 + 2*q3 + 2*q4))/2 + m4*(L3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2) + l4_y*np.cos(q2 + q3 + q4))*(L3_y*np.sin(q2 + q3) + L2_y*np.cos(q2) + L2_x*np.sin(q2) + l4_y*np.sin(q2 + q3 + q4)) + m3*(l3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2))*(L2_y*np.cos(q2) + l3_y*np.sin(q2 + q3) + L2_x*np.sin(q2)) - (l2_y**2*m2*np.sin(2*q2))/2) - dq4*np.sin(q2 + q3 + q4)*(Ixx4*np.cos(q2 + q3 + q4) - Izz4*np.cos(q2 + q3 + q4) + l4_y**2*m4*np.cos(q2 + q3 + q4) + L3_y*l4_y*m4*np.cos(q2 + q3) + L2_x*l4_y*m4*np.cos(q2) - L2_y*l4_y*m4*np.sin(q2)))
    P12 = U_lin*(-dq1*((Ixx3*np.sin(2*q2 + 2*q3))/2 - (Izz3*np.sin(2*q2 + 2*q3))/2 - (Ixx2*np.sin(2*q2))/2 + (Izz2*np.sin(2*q2))/2 + (Ixx4*np.sin(2*q2 + 2*q3 + 2*q4))/2 - (Izz4*np.sin(2*q2 + 2*q3 + 2*q4))/2 + m4*(L3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2) + l4_y*np.cos(q2 + q3 + q4))*(L3_y*np.sin(q2 + q3) + L2_y*np.cos(q2) + L2_x*np.sin(q2) + l4_y*np.sin(q2 + q3 + q4)) + m3*(l3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2))*(L2_y*np.cos(q2) + l3_y*np.sin(q2 + q3) + L2_x*np.sin(q2)) - (l2_y**2*m2*np.sin(2*q2))/2))
    P13 = U_lin*(-dq1*((Ixx3*np.sin(2*q2 + 2*q3))/2 - (Izz3*np.sin(2*q2 + 2*q3))/2 + (Ixx4*np.sin(2*q2 + 2*q3 + 2*q4))/2 - (Izz4*np.sin(2*q2 + 2*q3 + 2*q4))/2 + m4*(L3_y*np.sin(q2 + q3) + l4_y*np.sin(q2 + q3 + q4))*(L3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2) + l4_y*np.cos(q2 + q3 + q4)) + l3_y*m3*np.sin(q2 + q3)*(l3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2))))
    P14 = U_lin*(-dq1*np.sin(q2 + q3 + q4)*(Ixx4*np.cos(q2 + q3 + q4) - Izz4*np.cos(q2 + q3 + q4) + l4_y**2*m4*np.cos(q2 + q3 + q4) + L3_y*l4_y*m4*np.cos(q2 + q3) + L2_x*l4_y*m4*np.cos(q2) - L2_y*l4_y*m4*np.sin(q2)))
    P21 = -P12
    P22 = U_lin*(Keq + dq3*(L2_y*l4_y*m4*np.cos(q3 + q4) + L2_y*L3_y*m4*np.cos(q3) - L2_x*l4_y*m4*np.sin(q3 + q4) - L2_x*L3_y*m4*np.sin(q3) + L2_y*l3_y*m3*np.cos(q3) - L2_x*l3_y*m3*np.sin(q3)) - l4_y*m4*dq4*(L2_x*np.sin(q3 + q4) - L2_y*np.cos(q3 + q4) + L3_y*np.sin(q4)))
    P23 = U_lin*(L2_y*l4_y*m4*dq2*np.cos(q3 + q4) + L2_y*l4_y*m4*dq3*np.cos(q3 + q4) + L2_y*l4_y*m4*dq4*np.cos(q3 + q4) + L2_y*L3_y*m4*dq2*np.cos(q3) + L2_y*L3_y*m4*dq3*np.cos(q3) - L2_x*l4_y*m4*dq2*np.sin(q3 + q4) - L2_x*l4_y*m4*dq3*np.sin(q3 + q4) - L2_x*l4_y*m4*dq4*np.sin(q3 + q4) - L2_x*L3_y*m4*dq2*np.sin(q3) - L2_x*L3_y*m4*dq3*np.sin(q3) + L2_y*l3_y*m3*dq2*np.cos(q3) + L2_y*l3_y*m3*dq3*np.cos(q3) - L2_x*l3_y*m3*dq2*np.sin(q3) - L2_x*l3_y*m3*dq3*np.sin(q3) - L3_y*l4_y*m4*dq4*np.sin(q4))
    P24 = U_lin*(-l4_y*m4*(L2_x*np.sin(q3 + q4) - L2_y*np.cos(q3 + q4) + L3_y*np.sin(q4))*(dq2 + dq3 + dq4))
    P31 = -P13
    P32 = U_lin*(L2_x*l4_y*m4*dq2*np.sin(q3 + q4) - L2_y*L3_y*m4*dq2*np.cos(q3) - L2_y*l4_y*m4*dq2*np.cos(q3 + q4) + L2_x*L3_y*m4*dq2*np.sin(q3) - L2_y*l3_y*m3*dq2*np.cos(q3) + L2_x*l3_y*m3*dq2*np.sin(q3) - L3_y*l4_y*m4*dq4*np.sin(q4))
    P33 = U_lin*(Keq - L3_y*l4_y*m4*dq4*np.sin(q4))
    P34 = U_lin*(-L3_y*l4_y*m4*np.sin(q4)*(dq2 + dq3 + dq4))
    P41 = -P14
    P42 = U_lin*(l4_y*m4*(L3_y*dq2*np.sin(q4) + L3_y*dq3*np.sin(q4) - L2_y*dq2*np.cos(q3 + q4) + L2_x*dq2*np.sin(q3 + q4)))
    P43 = U_lin*(L3_y*l4_y*m4*np.sin(q4)*(dq2 + dq3))
    P44 = U_lin*(Keq)
    P  = np.array([[P11, P12, P13, P14], 
                [P21, P22, P23, P24], 
                [P31, P32, P33, P34],
                [P41, P42, P43, P44]], dtype=np.float64)
    ##########
    D2 = U_lin*(g*l2_y*m2*np.sin(q2) - g*m4*(L3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2) + l4_y*np.cos(q2 + q3 + q4)) - g*m3*(l3_y*np.cos(q2 + q3) + L2_x*np.cos(q2) - L2_y*np.sin(q2)))
    D3 = U_lin*(- g*m4*(L3_y*np.cos(q2 + q3) + l4_y*np.cos(q2 + q3 + q4)) - g*l3_y*m3*np.cos(q2 + q3))
    D4 = U_lin*(-g*l4_y*m4*np.cos(q2 + q3 + q4))
    d = np.array([[0], [D2], [D3], [D4]], dtype=np.float64)
    
    # APLICANDO LEY DE CONTROL
    
    dq_vec[0,0]=dq1
    dq_vec[1,0]=dq2
    dq_vec[2,0]=dq3
    dq_vec[3,0]=dq4

    u_vec[0,0]=u1
    u_vec[1,0]=u2
    u_vec[2,0]=u3
    u_vec[3,0]=u4
    if k==0:
        print(M,"\n")
        print(P,"\n")
        print(d,"\n")
        print(dq_vec,"\n")
        print(u_vec,"\n")

    
    dq_vec = dq_vec + T * np.linalg.solve(M, u_vec - np.dot(P, dq_vec) - d)
    
    
    dq1 = dq_vec[0]
    dq2 = dq_vec[1]
    dq3 = dq_vec[2]
    dq4 = dq_vec[3]
    
    q1 = q1 + T * dq_vec[0]
    q2 = q2 + T * dq_vec[1]
    q3 = q3 + T * dq_vec[2]
    q4 = q4 + T * dq_vec[3]
    
    Q1[0,k]=q1
    Q2[0,k]=q2
    Q3[0,k]=q3
    Q4[0,k]=q4
"""
end_time = time.time()
execution_time = end_time - start_time
print("Tiempo de ejecución: ", execution_time, " segundos")
# GRAFInp.cos
# Graficar Q1 y Qd1
Qd1p=np.transpose(Qd1)
Q1p=np.transpose(Q1)
Qd2p=np.transpose(Qd2)
Q2p=np.transpose(Q2)
U1p=np.transpose(U1)
U2p=np.transpose(U2)
ejex = np.linspace(0, nn*T, nn)
print("Plots:\n")

plt.subplot(411)
plt.plot(ejex, Qd1p, ejex, Q1p)
plt.grid(True)
plt.ylabel('q1 [rad]')

# Graficar U1
plt.subplot(412)
plt.plot(ejex, U1p ,'m')
plt.grid(True)
plt.xlabel('TIEMPO   [s]')
plt.ylabel('u1 [V]')

# Graficar Q2 y Qd2
plt.subplot(413)
plt.plot(ejex, Qd2p, ejex, Q2p)
plt.grid(True)
plt.xlabel('TIEMPO   [s]')
plt.ylabel('q2 [rad]')

# Graficar U2
plt.subplot(414)
plt.plot(ejex, U2p, 'm')
plt.grid(True)
plt.xlabel('TIEMPO   [s]')
plt.ylabel('u2 [V]')

plt.show()
"""
# Out:
# [[0.00658119 0.         0.         0.        ]
#  [0.         0.00966246 0.00365406 0.00040086]
#  [0.         0.00365406 0.00734517 0.00143023]
#  [0.         0.00040086 0.00143023 0.00318381]]
#
# [[ 6.78925035e-05  0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#  [-0.00000000e+00  6.78925035e-05  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  6.78925035e-05  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -0.00000000e+00  6.78925035e-05]]
#
# [[0.00000000e+00]
#  [2.90597897e-01]
#  [2.18317947e-01]
#  [4.81231109e-18]]
#
# [[0.]
#  [0.]
#  [0.]
#  [0.]]
#
# [[ 0.        ]
#  [35.13635268]
#  [13.64514208]
#  [41.16402332]]
# ...

# %%
# #np.nanmin(U1)
# Qd1p=np.transpose(Qd1)
# Qd1p.shape
